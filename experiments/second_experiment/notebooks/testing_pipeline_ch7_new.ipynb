# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
from loguru import logger

from src.text_embedder.embedder import EmbeddingsModel

from pathlib import Path
import os
# Out:
# C:\Users\baatout\PycharmProjects\afm-vlm\.venv\Lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %% [markdown]
# # Load Data

# %%
notebook_path = Path().resolve().parent
print(notebook_path)

# Construct the filename relative to the new path
filename = notebook_path / "test_frames_ch7.csv"

# Read the CSV file
df = pd.read_csv(filename)
print(df)
# Out:
# C:\Users\baatout\PycharmProjects\afm-vlm\experiments\second_experiment
#     ID                                             Prompt Length  GT_Keyframe
# 0    1                                 What are feedlots?  short           47
# 1    2                                What is weathering?  short           17
# 2    3  What is desertification and how much productiv...   long           22
# 3    4  What is the conservation reserve programm of 1...   long           29
# 4    5          GM crops today are engineered to resist:    long           56
# 5    6  90% of energy is lost from one trophic level t...   long           45
# 6    7                               Risks of biocontrol?  short           40
# 7    8  As the populations increases pesticides lose t...   long           38
# 8    9  Substainable fertilizer use involves monitorin...   long           36
# 9   10                               What is overgrazing?  short           29
# 10  11                   Why does the USDA issues labels?  short           71
# 11  12                 How productive is organic farming?  short           69
# 12  13           What does soil in organic plots contain?   long           68
# 13  14  3 out of 4 Americans buy organic food at least...   long           65
# 14  15                      What are the farmer benefits?  short           64
# 15  16                         What are the farmer risks?  short           64
# 16  17              What are the obstacles for consumers?  short           64
# 17  18                                  What is terracing  short           26
# 18  19  people think that "tinkering" with food but ot...   long           61
# 19  20  gm foos resistance to the week killer is being...   long           59
# 20  21                 When dod the dust bowl took place?  short           23

# %%
# create dataframe to save results of the experiments
columns = ['Prompt', 'GT_Keyframe', 'Top_1', 'Top_2', 'Top_3']

df_test = pd.DataFrame(columns=columns)

df_ocr_only = df_test
df_ocr_lava = df_test
df_ocr_transcriptions = df_test

df_short_llm_summary = df_test
df_extensive_summary = df_test

# %%
def add_to_df(prompt, gt_keyframe, result):
    # Create a new row with the provided data
    return {
        'Prompt': prompt,
        'GT_Keyframe': gt_keyframe,
        'Top_1': extract_keyframe_number(result[0]) if len(result) > 0 else None,
        'Top_2': extract_keyframe_number(result[1]) if len(result) > 1 else None,
        'Top_3': extract_keyframe_number(result[2]) if len(result) > 2 else None
    }


# ietrate over the dataframe and get the results
def get_results(df):
    for _, row in df.iterrows():
        logger.info(row['Prompt'])
        prompt = row['Prompt']
        gt_keyframe = row['GT_Keyframe']

        # Search for similar images
        output = embedding_model.search_similar_images_top_k(prompt, gt_keyframe, 3)
        res_row = add_to_df(prompt, gt_keyframe, output)
        rows.append(res_row)

    return rows


def extract_keyframe_number(path):
    """
    Extracts the scene number from the given file path.

    Parameters:
    path (str): The full path of the file.

    Returns:
    str: The extracted scene number.
    """
    # Get filename without extension
    filename = os.path.splitext(os.path.basename(path))[0]

    # Extract '032' from filename
    scene_number = filename.split('-Scene-')[-1].split('-')[0]

    return scene_number

# %%
#top_3 = []
#embedding_model.check_proximity_keyframes(90, top_3)

# %% [markdown]
# # LOAD MODEL

# %%
embedding_model = EmbeddingsModel()

# %%
csv = notebook_path / "ch7_soil_agriculture.csv"
df_data_extensive = pd.read_csv(csv)
df_data_extensive
# Out:
#                            Unnamed: 0  \
# 0                            img_path
# 1                          timestamps
# 2                       transcription
# 3                  ocr_extracted_text
# 4                        llava_result
# 5                           clip_text
# 6                    llm_long_summary
# 7                 clip_text_embedding
# 8                clip_image_embedding
# 9             standard_text_embedding
# 10           extensive_text_embedding
# 11                 ocr_text_embedding
# 12       transcription_text_embedding
# 13               llava_text_embedding
# 14        ocr_transcription_embedding
# 15  ocr_transcription_llava_embedding
#
#                                                    47  \
# 0   /Users/magic-rabbit/Documents/AFM/afm-vlm/data...
# 1                                    [2538.0, 2567.0]
# 2    Feed lots are factory farms are also called c...
# 3   + Feedlots (factory farms)\r\n* Also called co...
# 4    The image you've provided appears to be a sli...
# 5   Feedlots factory farms CAFOs high-density anim...
# 6   Feedlots, also called concentrated animal feed...
# 7   tensor([[ 4.0393e-02, -3.8633e-02, -1.1908e-02...
# 8   tensor([[ 2.1739e-02, -6.4891e-02, -2.4380e-03...
# 9   tensor([ 1.2929e-02, -7.4021e-02, -4.7234e-02,...
# 10  tensor([-3.1054e-01, -2.1256e-01, -9.3953e-02,...
# 11  tensor([-1.1626e-01, -3.0608e-02,  3.9430e-02,...
# 12  tensor([ 1.6078e-01, -1.5256e-01, -3.8168e-02,...
# 13  tensor([-0.1007, -0.0871,  0.1055, -0.0151,  0...
# 14  tensor([-4.0239e-02, -9.7657e-02,  7.2754e-02,...
# 15  tensor([-4.0239e-02, -9.7657e-02,  7.2754e-02,...
#
#                                                    59  \
# 0   /Users/magic-rabbit/Documents/AFM/afm-vlm/data...
# 1                                    [2965.4, 2975.2]
# 2    Resistance to the weed killer glyphosate is b...
# 3   Resistance to the weed-\r\n\r\nkiller glyphosa...
# 4    The image you've provided appears to be a sli...
# 5   Glyphosate resistance, weed killer toxicity, h...
# 6   Resistance to glyphosate, a toxic chemical use...
# 7   tensor([[ 9.8381e-03,  1.6149e-03,  4.9091e-03...
# 8   tensor([[ 3.4175e-03, -4.0429e-04, -2.3348e-02...
# 9   tensor([-0.2132,  0.1878, -0.0305, -0.0968,  0...
# 10  tensor([-2.9115e-01,  7.7240e-02, -8.7239e-02,...
# 11  tensor([-0.3148,  0.1239, -0.0787, -0.0482,  0...
# 12  tensor([-2.1352e-01,  1.4427e-01, -1.9891e-01,...
# 13  tensor([-2.7367e-01, -2.0876e-02,  1.2253e-01,...
# 14  tensor([-1.7349e-01,  1.1662e-01, -1.8165e-01,...
# 15  tensor([-2.3667e-01,  1.0299e-01, -3.7374e-02,...
#
#                                                    24  \
# 0   /Users/magic-rabbit/Documents/AFM/afm-vlm/data...
# 1                                    [1457.9, 1482.9]
# 2    The Dust Bowl prompted the U.S. to fight eros...
# 3   * Soil Conservation Service (SCS)\r\n* Started...
# 4    The image you've provided appears to be a scr...
# 5   Soil Conservation Service (SCS), started in 19...
# 6   The Soil Conservation Service (SCS) was starte...
# 7   tensor([[-1.7851e-03, -3.0845e-03, -2.0621e-02...
# 8   tensor([[-0.0384, -0.0140,  0.0101,  0.0104, -...
# 9   tensor([-3.5061e-01, -9.6885e-02, -3.7276e-01,...
# 10  tensor([-4.0123e-01, -1.0093e-01, -4.4535e-01,...
# 11  tensor([-0.3447, -0.0514, -0.2841,  0.1297, -0...
# 12  tensor([ 0.0143, -0.0869,  0.0278, -0.0071,  0...
# 13  tensor([-0.0805, -0.0470,  0.1954, -0.0309,  0...
# 14  tensor([-0.2747, -0.1069, -0.2102,  0.0264, -0...
# 15  tensor([-0.2581, -0.1071, -0.1875,  0.0312, -0...
#
#                                                    55  \
# 0   /Users/magic-rabbit/Documents/AFM/afm-vlm/data...
# 1                                    [2870.2, 2884.6]
# 2    Biotechnology is transforming the products ar...
# 3   Biotec’\r\n\r\naround\r\n\r\nnology is transfo...
# 4    The image you've provided appears to be a sli...
# 5   Biotechnology transforming products, GM foods ...
# 6   Biotechnology is transforming products around ...
# 7   tensor([[ 2.8391e-02,  1.4795e-02,  3.1949e-03...
# 8   tensor([[-2.1004e-02,  4.3992e-03, -3.4597e-02...
# 9   tensor([-1.5475e-01,  2.4093e-02,  7.9241e-02,...
# 10  tensor([-1.0035e-01,  4.7902e-02,  1.7075e-01,...
# 11  tensor([ 0.1163,  0.2098,  0.1544, -0.2062,  0...
# 12  tensor([ 2.6045e-02,  1.0183e-03,  1.8241e-01,...
# 13  tensor([-2.6566e-01, -8.4487e-02,  1.3664e-01,...
# 14  tensor([ 0.1657,  0.1858,  0.1820, -0.1831,  0...
# 15  tensor([ 1.4713e-01,  1.7342e-01,  2.2969e-01,...
#
#                                                    28  \
# 0   /Users/magic-rabbit/Documents/AFM/afm-vlm/data...
# 1                                    [1580.1, 1702.6]
# 2    By increasing organic matter and soil biodive...
# 3   Sustainable agriculture begins with soil\r\nma...
# 4    The slide appears to be from an academic lect...
# 5                                                 NaN
# 6   Sustainable agriculture begins with soil manag...
# 7   tensor([[ 7.7999e-03,  1.8883e-02,  9.8074e-03...
# 8   tensor([[-1.6251e-02, -3.4161e-02,  1.9406e-03...
# 9   tensor([ 2.2692e-01,  8.1784e-02,  2.3543e-02,...
# 10  tensor([ 0.1384,  0.2182,  0.0390,  0.0169,  0...
# 11  tensor([ 0.2063,  0.2499,  0.1000, -0.0231,  0...
# 12  tensor([ 6.4776e-02,  1.6517e-01,  1.3826e-01,...
# 13  tensor([ 2.0335e-02,  1.5398e-01,  1.1334e-01,...
# 14  tensor([ 1.7835e-01,  2.1846e-01,  1.1210e-01,...
# 15  tensor([ 1.7835e-01,  2.1846e-01,  1.1210e-01,...
#
#                                                    36  \
# 0   /Users/magic-rabbit/Documents/AFM/afm-vlm/data...
# 1                                    [2012.5, 2082.4]
# 2    Sustainable approaches to fertilizing deliver...
# 3   * Sustainable approaches to fertilizing delive...
# 4    The image you've provided appears to be a sli...
# 5   Sustainable fertilizing approaches deliver nut...
# 6   Sustainable approaches to fertilizing deliver ...
# 7   tensor([[ 1.7022e-02,  5.4097e-03,  1.8379e-02...
# 8   tensor([[-0.0350, -0.0486,  0.0394,  0.0250, -...
# 9   tensor([-9.0202e-02,  1.7775e-01,  9.7417e-02,...
# 10  tensor([-4.5420e-02,  2.0959e-01,  3.2850e-02,...
# 11  tensor([-6.3117e-02,  1.5388e-01,  6.5337e-02,...
# 12  tensor([-5.1078e-02,  1.7252e-01,  9.2805e-02,...
# 13  tensor([-9.2999e-03,  4.1862e-02,  1.6487e-01,...
# 14  tensor([-0.0552,  0.1623,  0.0664, -0.0349,  0...
# 15  tensor([-0.0552,  0.1623,  0.0664, -0.0349,  0...
#
#                                                    63  \
# 0   /Users/magic-rabbit/Documents/AFM/afm-vlm/data...
# 1                                    [3118.6, 3164.3]
# 2    The growth of sustainable agriculture.  Susta...
# 3   Sustainable agriculture keeps high crop yields...
# 4    The image you've provided appears to be a sli...
# 5   Sustainable agriculture high crop yields, mini...
# 6   Sustainable agriculture keeps high crop yields...
# 7   tensor([[ 1.2078e-02,  1.7814e-02,  5.1403e-03...
# 8   tensor([[ 3.1654e-02, -1.5540e-02,  3.6548e-02...
# 9   tensor([ 1.4203e-01,  1.8171e-01, -4.7989e-02,...
# 10  tensor([ 1.5695e-01,  1.3841e-01, -4.2443e-02,...
# 11  tensor([ 0.1742,  0.1006,  0.0151,  0.0534,  0...
# 12  tensor([ 9.1905e-02,  2.0517e-01, -5.6545e-02,...
# 13  tensor([-1.1084e-01,  1.0863e-01,  7.2340e-02,...
# 14  tensor([ 0.1175,  0.1223,  0.0397,  0.1002,  0...
# 15  tensor([ 0.1175,  0.1223,  0.0397,  0.1002,  0...
#
#                                                    71  \
# 0   /Users/magic-rabbit/Documents/AFM/afm-vlm/data...
# 1                                    [3347.2, 3387.0]
# 2    In weighing the issues, here are some items t...
# 3   * Do You Want Food Labeled?\r\n\r\n* The USDA ...
# 4    The slide appears to be from an academic lect...
# 5   Food labeling organic GMOs USDA standards cons...
# 6   The lecture discusses food labeling, specifica...
# 7   tensor([[ 1.8252e-02, -9.0988e-04, -7.8944e-03...
# 8   tensor([[ 1.5346e-02,  1.4449e-02, -2.2106e-03...
# 9   tensor([-0.0751,  0.1320,  0.0303, -0.1402,  0...
# 10  tensor([ 2.9512e-02,  2.0431e-01, -6.3637e-02,...
# 11  tensor([ 0.1524,  0.0325,  0.1538, -0.1026,  0...
# 12  tensor([ 1.2017e-01,  5.0166e-02,  1.8156e-01,...
# 13  tensor([ 4.3665e-02,  1.8651e-02,  1.0127e-01,...
# 14  tensor([ 1.4670e-01,  4.2743e-02,  1.7155e-01,...
# 15  tensor([ 1.4670e-01,  4.2743e-02,  1.7155e-01,...
#
#                                                    12  ...  \
# 0   /Users/magic-rabbit/Documents/AFM/afm-vlm/data...  ...
# 1                                      [738.9, 813.4]  ...
# 2    The desire for greater quantity and quality o...  ...
# 3   » Green Revolution\r\n* Drastically increased ...  ...
# 4    The slide appears to be from an academic lect...  ...
# 5   Green Revolution, Norman Borlaug, Nobel Peace ...  ...
# 6   The Green Revolution boosted food production t...  ...
# 7   tensor([[ 1.1573e-02, -2.3679e-02, -1.0352e-02...  ...
# 8   tensor([[-1.4534e-02, -7.7772e-03, -2.0481e-02...  ...
# 9   tensor([ 6.4370e-02,  2.6330e-01, -1.3370e-01,...  ...
# 10  tensor([-1.5118e-02,  1.4974e-01, -2.6894e-01,...  ...
# 11  tensor([-3.2454e-02,  2.6091e-01, -6.0734e-02,...  ...
# 12  tensor([-2.2306e-02,  1.2889e-01, -1.5974e-01,...  ...
# 13  tensor([ 0.1033, -0.0556,  0.0534, -0.0575,  0...  ...
# 14  tensor([ 0.0009,  0.1291, -0.0626,  0.1221,  0...  ...
# 15  tensor([ 0.0009,  0.1291, -0.0626,  0.1221,  0...  ...
#
#                                                    68  \
# 0   /Users/magic-rabbit/Documents/AFM/afm-vlm/data...
# 1                                    [3279.2, 3294.1]
# 2    Modern's team found that soil and organic plo...
# 3   The Science Behind the Story (cont’d)\r\n\r\n»...
# 4    The image you've provided appears to be a sli...
# 5                                                 NaN
# 6   The lecture discussed the science behind organ...
# 7   tensor([[ 7.7999e-03,  1.8883e-02,  9.8074e-03...
# 8   tensor([[ 8.4629e-03, -1.3382e-02,  1.0448e-02...
# 9   tensor([ 2.2692e-01,  8.1784e-02,  2.3543e-02,...
# 10  tensor([ 6.7524e-02,  5.6519e-02, -2.3248e-01,...
# 11  tensor([ 0.1935,  0.0851, -0.0193,  0.0322,  0...
# 12  tensor([ 1.4497e-01, -1.9733e-01, -1.4441e-02,...
# 13  tensor([-2.9971e-02,  5.7195e-02,  6.1441e-02,...
# 14  tensor([ 1.9988e-01,  3.8487e-02, -4.7509e-02,...
# 15  tensor([ 1.9995e-01,  5.3093e-02, -1.1956e-02,...
#
#                                                    15  \
# 0   /Users/magic-rabbit/Documents/AFM/afm-vlm/data...
# 1                                      [882.5, 957.0]
# 2    We can't simply keep expanding agriculture in...
# 3   » Suitable farmland is disappearing\r\n+ We mu...
# 4    The image you've provided appears to be a sli...
# 5   Sustainable agriculture, low-input agriculture...
# 6   Sustainable agriculture is crucial to reduce e...
# 7   tensor([[ 7.9727e-03,  5.5967e-03, -4.6935e-03...
# 8   tensor([[ 2.8608e-02, -3.2457e-02,  2.7514e-02...
# 9   tensor([ 2.4527e-01,  3.3436e-01,  1.7639e-01,...
# 10  tensor([ 0.1270,  0.3047,  0.1384,  0.1356,  0...
# 11  tensor([ 4.1365e-02,  2.9827e-01,  1.8890e-01,...
# 12  tensor([ 0.1192,  0.1792,  0.1517,  0.0628,  0...
# 13  tensor([ 9.7076e-02,  1.5541e-01,  1.8686e-01,...
# 14  tensor([ 5.4038e-02,  2.5335e-01,  2.1501e-01,...
# 15  tensor([ 5.4038e-02,  2.5335e-01,  2.1501e-01,...
#
#                                                    33  \
# 0   /Users/magic-rabbit/Documents/AFM/afm-vlm/data...
# 1                                    [1873.0, 1946.0]
# 2    Sustainable approaches to irrigation maximize...
# 3   * Match crops and climate\r\n\r\n* Don't plant...
# 4    The slide appears to be from an academic lect...
# 5   Sustainable irrigation, crop matching, climate...
# 6   Sustainable approaches to irrigation maximize ...
# 7   tensor([[-7.8933e-03,  1.7348e-02,  7.0237e-03...
# 8   tensor([[-3.5153e-02,  6.8040e-03, -4.1972e-03...
# 9   tensor([ 0.1232,  0.0803,  0.0666,  0.0357,  0...
# 10  tensor([ 1.5432e-01,  2.8252e-01,  1.2426e-01,...
# 11  tensor([ 0.0319,  0.0529,  0.2925,  0.0254,  0...
# 12  tensor([ 0.1017,  0.4300,  0.1722, -0.0081,  0...
# 13  tensor([-6.0778e-02,  2.3760e-02,  1.1369e-01,...
# 14  tensor([ 7.0920e-02,  2.7796e-01,  2.3858e-01,...
# 15  tensor([ 7.0920e-02,  2.7796e-01,  2.3858e-01,...
#
#                                                    50  \
# 0   /Users/magic-rabbit/Documents/AFM/afm-vlm/data...
# 1                                    [2660.3, 2689.7]
# 2    The benefits are a reduced pressure on overha...
# 3   * Benefits\r\n* Reduces pressure on overharves...
# 4    The slide appears to be from an academic lect...
# 5   Aquaculture reduces pressure on overharvested ...
# 6   Aquaculture's benefits include reducing pressu...
# 7   tensor([[ 6.4607e-03, -2.9856e-02,  1.2888e-02...
# 8   tensor([[-3.4324e-02, -5.2919e-02, -2.8924e-02...
# 9   tensor([ 3.3718e-02,  1.7667e-01,  4.4021e-01,...
# 10  tensor([ 8.0028e-02, -3.7635e-02,  2.5187e-01,...
# 11  tensor([-0.1123,  0.1193,  0.2960,  0.0431,  0...
# 12  tensor([-0.1446,  0.0653,  0.1990,  0.0442,  0...
# 13  tensor([-1.9390e-01,  3.0541e-02,  2.9236e-01,...
# 14  tensor([-1.1706e-01,  1.2853e-01,  2.5900e-01,...
# 15  tensor([-1.1706e-01,  1.2853e-01,  2.5900e-01,...
#
#                                                    21  \
# 0   /Users/magic-rabbit/Documents/AFM/afm-vlm/data...
# 1                                    [1288.5, 1374.7]
# 2    maintaining healthy soils.  Soil degradation ...
# 3   * People make land more vulnerable to erosion ...
# 4    The image you've provided appears to be a sli...
# 5   Soil degradation, erosion, human activities, o...
# 6   Soil degradation is a significant issue caused...
# 7   tensor([[-4.8252e-03,  1.0867e-02, -6.5915e-03...
# 8   tensor([[ 9.7643e-03,  2.6059e-02,  8.8217e-03...
# 9   tensor([ 7.8327e-02, -1.7367e-02,  3.8126e-01,...
# 10  tensor([ 3.7744e-02, -5.5459e-02,  2.2107e-01,...
# 11  tensor([ 3.2721e-01,  4.0047e-02,  1.5283e-01,...
# 12  tensor([ 0.0684, -0.0353,  0.3044,  0.1365,  0...
# 13  tensor([-0.0987, -0.1281,  0.2144,  0.1657,  0...
# 14  tensor([ 2.0429e-01, -7.1976e-02,  1.6206e-01,...
# 15  tensor([ 2.0429e-01, -7.1976e-02,  1.6206e-01,...
#
#                                                    42  \
# 0   /Users/magic-rabbit/Documents/AFM/afm-vlm/data...
# 1                                    [2370.3, 2436.3]
# 2    Polynators are beneficial bugs worth preservi...
# 3   Not all insects are pests; some are absolutely...
# 4    The image you've provided appears to be a sli...
# 5   Pollinators vital insects, not all pests; over...
# 6   Not all insects are pests; some are absolutely...
# 7   tensor([[-1.2188e-02, -1.0249e-02,  1.3366e-03...
# 8   tensor([[ 1.4537e-02, -3.1537e-02,  1.0537e-02...
# 9   tensor([ 6.6266e-02,  3.6422e-03,  2.0233e-02,...
# 10  tensor([ 0.0098,  0.1599, -0.0761, -0.1502,  0...
# 11  tensor([ 3.3014e-02,  1.4249e-01, -1.2085e-01,...
# 12  tensor([-3.4221e-02, -8.6676e-02, -3.4737e-02,...
# 13  tensor([-6.1997e-02,  6.6237e-02,  1.6776e-01,...
# 14  tensor([ 5.7953e-02,  1.1247e-01, -8.7914e-02,...
# 15  tensor([ 5.7953e-02,  1.1247e-01, -8.7914e-02,...
#
#                                                    17  \
# 0   /Users/magic-rabbit/Documents/AFM/afm-vlm/data...
# 1                                    [1045.1, 1116.5]
# 2    Soil formation begins when the lithosphere's ...
# 3   » Parent material\r\n+ The base geologic mater...
# 4    The slide appears to be from an academic lect...
# 5   Soil formation parent material weathering biol...
# 6   Soil formation begins when parent material is ...
# 7   tensor([[-9.1023e-03,  3.2866e-02,  9.9062e-03...
# 8   tensor([[-5.6825e-02,  1.2457e-02, -1.6212e-03...
# 9   tensor([-0.0380,  0.0693,  0.2290,  0.0652,  0...
# 10  tensor([-5.2347e-02,  7.4743e-02,  3.0503e-01,...
# 11  tensor([-3.1182e-01,  1.4676e-01,  4.0375e-01,...
# 12  tensor([-1.4554e-01,  1.0136e-01,  3.4403e-01,...
# 13  tensor([-0.1808, -0.0863,  0.3455, -0.0647,  0...
# 14  tensor([-2.7810e-01,  1.0007e-01,  3.8631e-01,...
# 15  tensor([-2.7810e-01,  1.0007e-01,  3.8631e-01,...
#
#                                                     9  \
# 0   /Users/magic-rabbit/Documents/AFM/afm-vlm/data...
# 1                                      [444.7, 493.4]
# 2    If on Earth, we're going to enhance global fo...
# 3   » Agriculture\r\n\r\n+ Practice of raising cro...
# 4    The slide appears to be from an academic lect...
# 5   Agriculture, practice of raising crops and liv...
# 6   Agriculture: The lecture discussed agriculture...
# 7   tensor([[ 7.7318e-03,  1.2429e-02,  1.1256e-02...
# 8   tensor([[-4.7350e-03, -1.9214e-02,  1.6494e-03...
# 9   tensor([ 0.3785,  0.0747, -0.0310,  0.1335,  0...
# 10  tensor([ 2.1111e-01,  2.0905e-01,  6.2944e-03,...
# 11  tensor([ 3.3161e-01,  4.8245e-02,  1.2111e-01,...
# 12  tensor([ 1.7612e-01,  6.8260e-02, -4.0815e-02,...
# 13  tensor([-0.0456, -0.0520,  0.1798,  0.1600,  0...
# 14  tensor([ 1.3807e-01,  1.0964e-01,  1.3175e-02,...
# 15  tensor([ 1.3807e-01,  1.0964e-01,  1.3175e-02,...
#
#                                                     5  \
# 0   /Users/magic-rabbit/Documents/AFM/afm-vlm/data...
# 1                                      [261.1, 329.7]
# 2    Our goal will be food security, meaning that ...
# 3   * Food security\r\n* Guarantee of an adequate,...
# 4    The image you've provided appears to be a sli...
# 5   Food security guarantee adequate safe nutritio...
# 6   Food security refers to a guarantee of an adeq...
# 7   tensor([[ 4.4902e-03, -1.2531e-03,  8.3299e-03...
# 8   tensor([[ 1.6363e-02, -1.0218e-02,  1.0712e-02...
# 9   tensor([-1.2184e-01,  5.3161e-02, -2.1295e-01,...
# 10  tensor([ 0.0241,  0.1050, -0.2728, -0.0487,  0...
# 11  tensor([-0.0210,  0.1411, -0.0094,  0.0298,  0...
# 12  tensor([ 1.5282e-02,  9.9986e-03, -2.0364e-01,...
# 13  tensor([-0.0370,  0.1050,  0.0112,  0.0790,  0...
# 14  tensor([ 3.0522e-02,  1.4148e-01, -6.2367e-02,...
# 15  tensor([ 3.0522e-02,  1.4148e-01, -6.2367e-02,...
#
#                                                    66
# 0   /Users/magic-rabbit/Documents/AFM/afm-vlm/data...
# 1                                    [3229.6, 3253.0]
# 2    The US 2014 Farm Bill has provisions to direc...
# 3   * The U.S. 2014 Farm Bill has provisions to di...
# 4    The slide appears to be from an academic lect...
# 5   US Farm Bill aids organic agriculture, reduces...
# 6   The US 2014 Farm Bill has provisions to direct...
# 7   tensor([[ 5.8709e-03, -6.9822e-04,  3.2165e-03...
# 8   tensor([[ 3.3794e-02, -4.0049e-02,  2.0572e-02...
# 9   tensor([ 0.1246,  0.1261, -0.1530,  0.0370,  0...
# 10  tensor([ 1.1893e-01,  1.8246e-01, -1.9030e-01,...
# 11  tensor([ 0.1435,  0.1709, -0.1252,  0.0243,  0...
# 12  tensor([ 1.3301e-01,  2.3536e-01, -1.5719e-01,...
# 13  tensor([ 0.0378,  0.1242, -0.0335,  0.0426,  0...
# 14  tensor([ 0.1057,  0.1772, -0.1214,  0.0319,  0...
# 15  tensor([ 0.1034,  0.1684, -0.1155,  0.0377,  0...
#
# [16 rows x 74 columns]

# %%
# get llm_long_summary 
llm_long_summary = df_data_extensive.iloc[6].to_dict().values()

# convert to list
llm_long_summary = list(llm_long_summary)
llm_long_summary = llm_long_summary[1:]
logger.info(llm_long_summary)
# Out:
# 2024-07-13 13:11:23.611 | INFO     | __main__:<module>:7 - ["Feedlots, also called concentrated animal feeding operations (CAFOs), are huge warehouses or pens that deliver food to animals living at extremely high densities. They produce over half of the world's pork and most of its poultry. The benefits include allowing greater production of affordable meat and reducing grazing impacts on land.", 'Resistance to glyphosate, a toxic chemical used as a herbicide, is being documented more widely than in the past. Glyphosate-resistant species are emerging, with over 900 studies documenting its harmful effects in the past 20 years. The use of glyphosate has increased significantly over time, particularly after the introduction of genetically modified foods. This raises concerns about the potential health risks associated with consuming GM foods and highlights the need for regulation and monitoring of glyphosate usage.', 'The Soil Conservation Service (SCS) was started in 1935 by Congress to fight erosion and soil conservation services. It works with farmers to develop conservation plans for farms. The SCS is now named the Natural Resources Conservation Service. Other countries also started their own conservation agencies. The Dust Bowl prompted the United States to take action, leading to the creation of the SCS.', 'Biotechnology is transforming products around us. GM foods have gone from science fiction to mainstream agriculture in the last three decades. The slide presents a graph showing the growth of GM foods, mainstream agriculture, and developing nations over time. It also highlights the significant patent activity in biotechnology compared to other areas. The lecture discusses how biotechnology has impacted various products and industries, particularly focusing on GM foods and their transition from being seen as science fiction to becoming mainstream in agriculture.', 'Sustainable agriculture begins with soil management. No-till farming and conservation tillage improve soil quality by increasing organic matter, reducing erosion, and storing carbon. Critics argue that no-till farming requires more chemical herbicides, while proponents point out that many farmers rely on green manures and cover crops to reduce weeds and synthetic fertilizers. The approach is not practical for large-scale intensive agriculture, but farmers are educating themselves and choosing approaches best for their farms.', "Sustainable approaches to fertilizing deliver nutrients directly to plant roots and avoid overapplication. This includes adding fertilizers to drip irrigation water, using no-till or low-till systems that inject fertilizers with seeds, monitoring soil nutrients and adding only when they're low, and capturing nutrient runoff through strips of vegetation along field edges and streams. Organic fertilizers can also be used, which improve soil structure, nutrient retention, and overall productivity. The preferred approach is to integrate inorganic and organic fertilizer systems.", 'Sustainable agriculture keeps high crop yields, minimizes resource use, and decreases environmental impacts. Organic agriculture uses no synthetic fertilizers, insecticides, fungicides, or herbicides. The Organic Food Production Act (1990) established national standards for organic products. The USDA issued criteria in 2000 by which food could be labeled organic. California, Washington, and Texas have passed stricter guidelines for labeling.', 'The lecture discusses food labeling, specifically whether products should be labeled as organic or genetically modified. The USDA issues labels to certify that products claiming to be organic have met government standards. Critics of genetically modified food want GM products to be labeled as well. The lecture raises questions about consumer awareness and the potential environmental consequences of such labeling practices.', "The Green Revolution boosted food production through new technology, crop varieties, and farming pra ...

# %%
# get ocr_only
# Since ocr_only embeddings can't be mapped to floats due to e-02, e-01, we're generating new embeddings 
ocr_only = df_data_extensive.iloc[3].to_dict().values()

# convert to list
ocr_only = list(ocr_only)

ocr_only = ocr_only[1:]

for i in ocr_only:
    logger.info(i)
# Out:
# 2024-07-13 13:11:23.910 | INFO     | __main__:<module>:11 - + Feedlots (factory farms)
# * Also called concentrated animal feeding operations
# (CAFOs)
# + Huge warehouses or pens deliver food to animals living
# at extremely high densities
# * Produce over half of the world’s pork and most of its
# poultry
# * Benefits
# * Allow greater production of affordable meat
# * Reduce grazing impacts on the land
#
#
# 2024-07-13 13:11:23.915 | INFO     | __main__:<module>:11 - Resistance to the weed-
#
# killer glyphosate is being
# documented more widely
# than in the past
#
# Clyphosateesistant species
#
#
# 2024-07-13 13:11:23.915 | INFO     | __main__:<module>:11 - * Soil Conservation Service (SCS)
# * Started in 1935 by Congress
# * Works with farmers to develop conservation plans for
# farms
# + Now named the Natural Resources Conservation
# Service
# Other countries started their own conservation
# agencies
#
#
# 2024-07-13 13:11:23.917 | INFO     | __main__:<module>:11 - Biotec’
#
# around
#
# nology is transform
#
# the produ
#
# * GM foods have gone from science fiction to
# mainstream agriculture in the last 3 decades
#
# 180 5
#
# 460 | — World total ;
# 440 | — Industrialized nations
# 420 | — Developing nations
#
# 100
# 80 4
# 60
# 40
# 20
#
# ns of hectares planted
# in GM crops
#
#
# 2024-07-13 13:11:23.918 | INFO     | __main__:<module>:11 - Sustainable agriculture begins with soil
# management (cont'd)
# * No-till drill
#
# * Cuts furrow
#
# * Drops in a seed
#
# * Closes furrow over seed
# * Critics of no-till farming
#
# in U.S.
#
# + Argue that it requires
# more use of chemical herbicides
#
# +» Proponents
#
# + Point out that many farmers rely more heavily on green
# manures by rotating cover crops
#
#
# 2024-07-13 13:11:23.919 | INFO     | __main__:<module>:11 - * Sustainable approaches to fertilizing delivers
# nutrients directly to plant roots and avoids
# overapplication
#
# * Add fertilizers to drip irrigation water
#
# + No-till or low-till systems inject fertilizers with seeds
#
# * Monitor soil nutrients and add only when they are low
#
# + Strips of vegetation along field edges and streams
#
# capture nutrient runoff
#
# Organic fertilizers add nutrients and organic matter
#
# + Improving soil structure, nutrient and water retention
# Preferred approach is to integrate inorganic and
# organic fertilizer systems
#
#
# 2024-07-13 13:11:23.920 | INFO     | __main__:<module>:11 - Sustainable agriculture keeps high crop yields,
# minimizes resource use, and decreases
# environmental impacts
# Organic agriculture
# + Uses no synthetic fertilizers, insecticides, fungicides, or
# herbicides
# Organic Food Production Act (1990) established
# national standards for organic products
# * The USDA issued criteria in 2000 by which food could be
# labeled organic
# * California, Washington, Texas passed stricter guidelines
# for labeling
#
#
# 2024-07-13 13:11:23.920 | INFO     | __main__:<module>:11 - * Do You Want Food Labeled?
#
# * The USDA issues labels to certify that products claiming
# to be organic have met the government's organic
# standards.
#
# * Critics of genetically modified food want GM products to
# be labeled as well.
#
# * Do you want your food labeled to indicate whether it is
# organic or genetically modified?
#
# + Would you choose among foods based on such labeling?
#
# + How might your food choices and purchasing decisions
# have environmental impacts (good or bad)?
#
#
# 2024-07-13 13:11:23.921 | INFO     | __main__:<module>:11 - » Green Revolution
# * Drastically increased food through new:
# + Technology
# + Crop varieties
# + Farming practices
# » Spread to the developing
# world in the 1940s
# + Wheat, rice, corn
# » Norman Borlaug
# + Won the Nobel Peace
# Prize for his work
#
#
# 2024-07-13 13:11:23.921 | INFO     | __main__:<module>:11 - eafood with ai
#
# * Worldwide fish populations are plummeting
# + Increased demand and technology
#
# » Aquaculture Other aquatic animals
# * Raising aquatic organisms |
# ina controlled environment =
#
# Open-water pens or
# land-based ponds
# The fastest-growing type on ee
# of food production (49.6%)
# Most widespread in Asia
# ‘Aquatic plants
# (41%)
#
#
# 2024-07-13 13:11:23.921 | INFO     | __main__:<module>:11 - * Fertilizers
# * Substances containing essential nutrients to enhance
# crop production
# * Inorganic fertilizers
# * Mined or synthetically manufactured mineral
# supplements
# Organic fertilizers
# * The remains or wastes of organisms
# * Manure, crop residues, fresh vegetation (green manure)
# + Compost
# Produced when decomposers break down organic matter
#
#
# 2024-07-13 13:11:23.921 | INFO     | __main__:<module>:11 - Biotechnology is transforming the products
# around us (cont'd)
#
# » Soybeans are the most om
# common type of GM
# crop
#
# + The United States leads
# the world in GM crops
#
#
# 2024-07-13 13:11:23.921 | INFO     | __main__:<module>:11 - Sustainable agriculture begins with soil
# management (cont'd)
# * Terracing
#
# + Level platforms cut into steep
# hillsides
#
# * This “staircase” contains rain
# and irrigation water
#
# + Intercrepping
# + Plantirig different crops in
# alternating bands
# + Increases ground cover
# * Decreases pests and disease
# * Replenishes soil
#
#
# 2024-07-13 13:11:23.926 | INFO     | __main__:<module>:11 - Our food choices are also energy choices
#
# +» Eating meat is far less energy-efficient than eating
#
# crops
#
# + 90% of energy is lost from
# one trophic level to the next
#
# * Some animals convert grain
# into meat more efficiently
# than others
#
#
# 2024-07-13 13:11:23.926 | INFO     | __main__:<module>:11 - Pests evolve resistance to pesticides
#
# Individuals that can metabolize and detoxify a
# pesticide survive and pass these genes to their
# offspring
#
# As the population increases, pesticides lose their
# effectiveness
#
# RS Ber pins
# YS
#
#
# 2024-07-13 13:11:23.926 | INFO     | __main__:<module>:11 - * Traditional agriculture
#
# * Uses human/animal power, hand tools, simple machines
#
# * Plant polycultures
# Different crops are planted in one field
#
# Industrial agriculture
# * Uses large-scale machines and fossil fuels to boost
# yields
#
# * Also uses irrigation, fertilizers, and pesticides
#
# * Plant monocultures
# Planting a single, genetically similar crop
# More efficient but reduces diversity; is disease prone
# Narrows the human diet
# Used in industrial agriculture
#
#
# 2024-07-13 13:11:23.926 | INFO     | __main__:<module>:11 - + Industrialized agriculture has had substantial
# negative environmental consequences
# * To support 9 billion humans, we must shift to
# sustainable agriculture to prevent further land
# degradation
# * Biological pest control, organic agriculture
# * Pollinator protection, preservation of native crops
# * Sustainable aquaculture
# * Careful, responsible genetic modification of food
#
#
# 2024-07-13 13:11:23.926 | INFO     | __main__:<module>:11 - This lecture will help you understand:
#
# * Challenges of feeding a growing human population
#
# * Different types of agriculture
#
# « The Green Revolution
#
# * The importance of soil
#
# * Soil erosion and
# degradation
#
# * Soil conservation
#
# + Irrigation, fertilizers, pests =
#
# + Genetic engineering
#
# + Animals raised for food
#
# * Organic agriculture
#
#
# 2024-07-13 13:11:23.926 | INFO     | __main__:<module>:11 - Many people think that “tinkering” with food supply
# is dangerous or morally wrong
#
# * Others fear that global food supply is dominated by
# large corporations that develop GM technologies
# Agrobiotech corporations have taken out patents on
# transgenes
#
# * Although Americans have accepted GM foods,
# consumers in Europe, Japan, and other nations are
# still uneasy about GM foods
#
# * 60+ nations require labeling of GM foods
#
#
# 2024-07-13 13:11:23.926 | INFO     | __main__:<module>:11 - 1000
# 3 200
# = 200
# = 700
# 600
# 500
# 400
# 300
# 200
# 100
# o
# Kd
# 4
#
# Number of people
# undernourished
#
# Percentage of people
# undernourished
#
# Year
#
# 0
#
# Percentage of people in developing
# nations who are undernourished
#
#
# 2024-07-13 13:11:23.926 | INFO     | __main__:<module>:11 - A soil profile consists of layers known as
# horizons
# » Horizons
# + The six layers of soil
# * Soil profile norton
# * Cross-section of soil as a whole
# + Leaching
#
# + Movement of dissolved particles snus
# down through horizons
#
# + Can deprive plants of nutrients crews
# * Topsoil
# * Inorganic and organic material
# most nutritive for plants
# + Vital for agriculture
#
#
# 2024-07-13 13:11:23.926 | INFO     | __main__:<module>:11 - nic agriculture is booming
#
# + 3 out of 4 Americans buy organic food at least
#
# occasionally
#
# * Production of organic food is increasing with
#
# demand
#
# iF
# i
#
# PPPOE P OES
#
#
# 2024-07-13 13:11:23.926 | INFO     | __main__:<module>:11 - + Industrial agriculture
# + Has allowed food production to keep pace with
# population growth
# * But has many bad environmental and social effects
# Benefits
# + Increases crop yields while reducing pressure to develop
# natural areas for new farms
# Drawbacks
# * Water, fossil fuels, fertilizers, and pesticides worsen
# pollution, erosion, and desertification
# * Requires far more energy than traditional methods
# * Displaces low-income farmers who can't afford the
# technology, forcing them to move to cities
#
#
# 2024-07-13 13:11:23.926 | INFO     | __main__:<module>:11 - The Science Behind the Story (cont’d)
#
# » How Productive Is Organic Farming?
# * Organic crops
# + Equaled conventional crops in yield
#
# + Produced more profit
#
# * Required less energy input
#
# + Released fewer greenhouse
# gas emissions
#
#
# 2024-07-13 13:11:23.926 | INFO     | __main__:<module>:11 - Drylands
# * Arid and semi-arid environments that cover about 40% of
# Earth's land surface
# * Prone to desertification
# Desertification
# * Loss of more than 10% productivity due to erosion, soil
# compaction, deforestation, overgrazing, drought,
# salinization, water depletion, climate change
# + Endangers the food supply of 1 billion people in over 100
# countries
# Costing tens of billions of dollars each year
#
#
# 2024-07-13 13:11:23.926 | INFO     | __main__:<module>:11 - * Integrated pest management (IPM)
# * Incorporates numerous techniques to suppress pests,
# including:
# + Close monitoring of pest populations
# Biocontrol
# Synthetic chemical use when needed
# + Habitat alteration
# + Crop rotation
# Transgenic crops
# + Alternative tilage methods
# Mechanical pest removal
# + IPM in Indonesia increased rice yields 13% and
# eliminated subsidy payments
#
#
# 2024-07-13 13:11:23.926 | INFO     | __main__:<module>:11 - * Many nations spend billions to subsidize agriculture
# * 20% of a U.S. farmer's income comes from subsidies
# * Pros of subsidies
# * Protects farmers from uncertain weather
# * Cons of subsidies
# + Encourages farming of vulnerable land
# * Produces more food than needed, driving prices down
#
# * Critics propose that instead of relying on subsidies,
# farmers should buy insurance against losses
#
#
# 2024-07-13 13:11:23.926 | INFO     | __main__:<module>:11 - + Goal of genetic engineering
# * Put genes that code for desirable traits (rapid growth,
# nutrition, etc.) into organisms lacking those traits
# * Transgenic organism
# * An organism that contains DNA from another species
# * Transgenes
# The genes that have moved between organisms
# * Biotechnology
# * The application of biological science to create products
# derived from organisms
#
# + Ithas helped to develop medicines, clean up pollution,
# aid cancer research, dissolve blood clots, make better
# food
#
#
# 2024-07-13 13:11:23.926 | INFO     | __main__:<module>:11 - Mainutrition can lead to diseases
#
# » Kwashiorkor
# * Due to lack of protein or essential amino acids in the diet
# * Children who stop breast-feeding are most at risk
# * Bloated stomach, mental and physical disabilities
#
# * Marasmus
#
# * Due to protein deficiency
# and insufficient calories
#
# * Wasting of the body
# + Deficiency in iodine and
# vitamin A are also
# prevalent
#
#
# 2024-07-13 13:11:23.942 | INFO     | __main__:<module>:11 - Soils
#
# * Soil
# + Acomplex system consisting of
# disintegrated rock, organic matter,
# water, gases, nutrients,
# microorganisms
# * Arenewable resource that can
# be depleted if abused
# + Soil contains:
# + Dead and living microorganisms
# * Decaying material
# * Bacteria, fungi, worms, insects, burrowing animals
# * Soil influences ecosystems as much as climate,
# latitude, and elevation
#
#
# 2024-07-13 13:11:23.942 | INFO     | __main__:<module>:11 - » How Productive Is Organic Farming?
# * World's longest-running field experiments on organic
# farming are in Switzerland and Pennsylvania
# * After more than 21 years of studies, Dr. Paul Mader's
# team concluded that organic plots were highly efficient
# and represent “a realistic alternative to conventional
# farming’
#
#
# 2024-07-13 13:11:23.942 | INFO     | __main__:<module>:11 - @ race to feed the world
#
# * Food production currently exceeds population
# growth
# * But not everyone has enough to eat
# * By 2050 we will have to feed 9 billion people
#
#
# 2024-07-13 13:11:23.942 | INFO     | __main__:<module>:11 - * Despite the Green Revolution, relentless population
# growth demands more innovation to feed us
# * Scientists alter genes of organisms
# * Crop plants and livestock
# + Genetically modified organisms hold promise to
# enhance nutrition and agricultural efficiency
# » But the risks are not well understood, leading to
# anxiety and protest from:
# » Consumer advocates, small farmers, environmentalists,
# critics of big business
#
#
# 2024-07-13 13:11:23.942 | INFO     | __main__:<module>:11 - + Irrigation
# + Artificially providing water to support agriculture
# * Unproductive regions become productive farmland
# Waterlogging
# * Water suffocates roots in overirrigated soils
# * Salinization
# * The buildup of salts in surface soil layers
# * Worse in dryland areas
# Salinization inhibits production of 20% of irrigated
# cropland, costing over $11 billion/year
#
#
# 2024-07-13 13:11:23.942 | INFO     | __main__:<module>:11 - U.S. bees provide $15 billion/year in pollination
# services, but parasitic mites decimated populations
# * Beekeepers were driven to financial ruin
# Colony collapse disorder
# + Entire beehives have died
# * One-third of all U.S. honeybees have died
# * Causes are unknown but may involve:
# Insecticides
# New parasites
#
# Accombination of stresses that weaken bees’ immune systems.
# and destroy social communication
#
#
# 2024-07-13 13:11:23.942 | INFO     | __main__:<module>:11 - Regional differences in soil traits affect
# agriculture (cont'd)
# * Swidden agriculture
# * Used in tropical areas after cultivation
# * Aplot is left to regrow into forest
# + Temperate prairies
#
# * Have lower rainfall and less nutrient leaching, resulting in
# higher fertility
#
#
# 2024-07-13 13:11:23.942 | INFO     | __main__:<module>:11 - Chapter
#
# if
#
# Soil, Agriculture,
#
# and the Future
# of Food
#
#
# 2024-07-13 13:11:23.942 | INFO     | __main__:<module>:11 - + Is it safe to eat genetically modified foods?
#
#
# 2024-07-13 13:11:23.942 | INFO     | __main__:<module>:11 - * The Green Revolution and Population Growth
# * Do you think the Green Revolution has solved problems,
# deferred problems, or created new ones?
# * Which aspects of the Green Revolution do you thin help
# in the quest for sustainability, which do not, and why?
#
# * Have the benefits of the Green Revolution outweighed its
# costs?
#
#
# 2024-07-13 13:11:23.942 | INFO     | __main__:<module>:11 - Sustainable agriculture reduces fossil fuel use from
# long-distance transport of products
#
# * The average U.S. food product travels 1,000 miles
# Farmers’ markets
#
# * Provide fresh, locally grown food
#
# * Provide organic items and unique local varieties
# Community-supported agriculture (CSA)
#
# * Consumers pay farmers in advance for produce
#
# * Consumers get fresh food
#
# * Farmers get a guaranteed income
#
#
# 2024-07-13 13:11:23.942 | INFO     | __main__:<module>:11 - * Crop rotation
# * Growing different crops from
# one year to the next
# * Returns nutrients to soil
#
# * Prevents erosion, reduces
# pests
#
# * Wheat or corn and soybeans
#
# * Contour farming
#
# + Plowing perpendicularly
# across a hill
#
# + Furrows slow runoff
# and capture soil
#
#
# 2024-07-13 13:11:23.942 | INFO     | __main__:<module>:11 - » Mixed results on pesticide use
# + Insecticide use declined, but herbicide use increased
#
# * GM foods can advance sustainable agriculture
# * Grown with no-till farming
# * Drought resistant and high-yielding
#
# Problems with GM foods
#
# + Expensive
# * Little incentive to develop crops for small-scale farmers
#
#
# 2024-07-13 13:11:23.942 | INFO     | __main__:<module>:11 - + Land and water are needed
# to raise food for livestock
#
# + Eggs and chicken meat
# require the least
#
# * Producing beef requires the
# most
#
# » When we choose what to
# eat, we choose how we use
# resources
#
# qu
#
# (0) water required te produce 1k o tein
#
#
# 2024-07-13 13:11:23.942 | INFO     | __main__:<module>:11 - * Pest
# * Any organism that damages valuable crops
# » Weed
# + Any plant that competes with crops
# Pesticides
# * Poisons that target pest organisms
# + Examples
# Insecticides kill insects
# Herbicides kill plants
# Fungicides kill fungi
#
# + Exposure to synthetic pesticides can cause health
# problems for humans and other organisms
#
#
# 2024-07-13 13:11:23.942 | INFO     | __main__:<module>:11 - Humans keep over 3 billion cattle, sheep, and goats
# * Overgrazing
#
# * Too many animals eat too much of the plant cover and
# impede plant regrowth
#
# * Soil is degraded and compacted
# + Increased erosion makes it hard for plants to grow
# + Non-native plants invade, which are less palatable to
# livestock and outcompete native vegetation
# * 70% of the world’s rangeland is degraded, costing
# $23 billion/year
#
#
# 2024-07-13 13:11:23.957 | INFO     | __main__:<module>:11 - nan
# 2024-07-13 13:11:23.957 | INFO     | __main__:<module>:11 - * Sustainable agriculture mimics natural ecosystems
# + They operate in cycles and are internally stabilized by
# negative feedback loops
# Agricultural systems can be integrated with the
# surrounding ecosystems
# * Reducing environmental impacts from food production
# Making agriculture sustainable is crucial for all of us
#
#
# 2024-07-13 13:11:23.957 | INFO     | __main__:<module>:11 - + Industrial agriculture’s use of genetically similar
# crops has led to efforts to conserve wild relatives of
# crops
#
# * Wild crops contain genes we will need in the future
# * Seed banks
# + Institutions that store seed types
# * Seeds are collected, stored, and periodically planted
#
# + Wild crops must not be allowed to interbreed with
#
# genetically modified crops
# * To prevent introduction of GM crops into wild populations
#
#
# 2024-07-13 13:11:23.957 | INFO     | __main__:<module>:11 - * Ecological impacts of GM foods pose the greatest
# threat
# * GM oilseed rape was found hybridizing with wild mustard
# * Creeping bentgrass engineered for golf courses has
# pollinated wild grass up to 21 km away
# * Many experts think we should follow the
#
# precautionary principle and proceed with caution
# on GM foods
#
#
# 2024-07-13 13:11:23.957 | INFO     | __main__:<module>:11 - The Commons at Kennesaw Sate University
# * Committed to sustainability
#
# + Minimized: s
# Energy use Kas
# + Water consumption -f
# + Waste generation sem ame .
# * Provides biodiesel for ee
# vehicles aad a
#
# + Grows 20% of its produce
#
# + Food waste is converted to nutrient-rich liquid and
# provides fertilizer to campus farms
#
# Other schools are committed to sustainability as well
#
#
# 2024-07-13 13:11:23.961 | INFO     | __main__:<module>:11 - * GM crops today are engineered to resist:
# * Herbicides
# * Insect attack
# In U.S. today:
# + 90% of corn, soybeans, cotton, and canola consist of
# genetically modified strains
#
# Worldwide:
# * 4 out of 5 soybean and cotton plants are now transgenic
# % * 1 0ut of 3 com and canola plants
# * 70% of processed foods in U.S. stores contain GM
# ingredients
#
#
# 2024-07-13 13:11:23.961 | INFO     | __main__:<module>:11 - Fertilizers boost yields but can be ove
#
# (cont’d)
# + Inorganic fertilizers
# * Boosted global production in the late 1900s
# But also severely pollute
# * Leaching and runoff of inorganic fertilizers causes:
#
# Groundwater Wo
# contamination
#
# * Dead zones in
# water systems
# * Air pollution from
#
# evaporated nitrates
#
# (nitions of mt tone)
# 8
#
#
# 2024-07-13 13:11:23.961 | INFO     | __main__:<module>:11 - * Costs
# * 45% of the world’s grain is fed to livestock
# Which endangers food security for the world’s poor
# * Feedlots produce huge amounts of manure and urine
# + Can pollute surface water and groundwater
# * Crowded housing causes outbreaks in disease
# + Heavy use of antibiotics
#
# * Produces more greenhouse gases (CO,, methane,
# nitrous oxides) than automobile emissions
#
#
# 2024-07-13 13:11:23.961 | INFO     | __main__:<module>:11 - » Pesticides lose effectiveness as pests evolve
#
# resistance
#
# + “Pesticide treadmill”
#
# * Chemists increase the toxicity of pesticides to compete
# with resistant pests
#
# Over 586 species are resistant to 330 insecticides
#
# + Hundreds of weeds and plant diseases have
#
# evolved resistance to herbicides and pesticides
#
# * Many species have evolved resistance to multiple
#
# chemicals
#
# * Green peach aphid, Colorado potato beetle,
# diamondback moth
#
#
# 2024-07-13 13:11:23.961 | INFO     | __main__:<module>:11 - As wealth and commerce increase, so does
# consumption of meat, milk, and eggs
#
# * Since 1950, global meat production has increased
# fivefold, and per capita meat consumption has
# doubled
#
# 20
#
# —— ae Sees
# =
# .
# LPEPPPPOS OS
#
# Yeer
#
# Per-person global production
# ‘isipersonlyesr)
#
#
# 2024-07-13 13:11:23.961 | INFO     | __main__:<module>:11 - Sustainable agriculture begins with soil
# management (cont'd)
#
# * Shelterbelts (windbreaks)
# * Rows of trees planted along
# edges of fields
# * Slows the wind
# * Can be combined with
# intercropping
# » Conservation tillage
#
# + Residues of previous crops are &
# left in field to prevent erosion
#
# + Soil soaks up more water
# + No-till farming
#
# Ultimate form of conservation SES
# tillage
#
#
# 2024-07-13 13:11:23.961 | INFO     | __main__:<module>:11 - Biological control (biocontrol)
# + Uses a pest's predators or diseases to control the pest
# + Examples
# Parasitoid wasps
# Introduction cactus moth from Argentina to Australia
# * Risks of biocontrol
# * Organisms can't easily be controlled
# * Organisms can harm nontargets
#
# Example: cactus moths introduced to Caribbean istands spread
# to Florida and are eating native cacti in southeastern U.S.
#
#  Biocontrol must be carefully planned and regulated
#
#
# 2024-07-13 13:11:23.961 | INFO     | __main__:<module>:11 - The Dust Bowl prompted the United States to
# fight erosion
#
# + In late 1800 and early 1900,
# farmers and ranchers:
# + Grew wheat, grazed cattle
# + Removed native grasses
# * Dust Bowl
# * 1930s drought and erosion
# caused “black blizzards” of
# sand
# * Thousands of farmers left their
# land
# + Relied on governmental help to
# survive
#
#
# 2024-07-13 13:11:23.961 | INFO     | __main__:<module>:11 - Foods can be lly modified
#
# » Genetic engineering —
#
# * Laboratory manipulation of
# genetic material by adding,
#
# deleting, or modifying DNA = Gant
# Genetically modified (GM) VO
# organisms eg
#
# Organisms that have been
# genetically engineered using
#
# » Recombinant DNA
#
# + Combined DNA segments from
# multiple organisms
#
#
# 2024-07-13 13:11:23.961 | INFO     | __main__:<module>:11 - » Conservation Reserve Program (1985)
#
# * Farmers are paid to put highly erodible land in
# conservation reserves
#
# + Trees and grasses are planted instead of crops
# * Each dollar spent saves 1 ton of topsoil
# + Generates income for farmers
# + Improves water quality and provides habitat for wildlife
# + $1.8 billion/year protects 27 million acres
# + The 2014 Farm Bill limits protection to 24 million
# acres
#
#
# 2024-07-13 13:11:23.961 | INFO     | __main__:<module>:11 - » Farmer benefits
# * Lower input costs
# * Enhanced income
# + Reduced chemical pollution and soil degradation
# Farmer risks
# * Organic approaches must be used for 3 years before
# products become certified and sold at higher prices
# * Obstacle for consumers
# * Higher price for organic food, but many are willing to pay
# the price
# * Worldwide, sales surpassed $63 billion
#
#
# 2024-07-13 13:11:23.961 | INFO     | __main__:<module>:11 - In rainforests
#
# * Rain leaches minerals and nutrients, reducing their
# accessibility to roots
#
# + Rapid decomposition of leaf iter results in a thin topsoil
# layer with little humus
#
# + Farming quickly depletes the soil’s fertility
#
#
# 2024-07-13 13:11:23.961 | INFO     | __main__:<module>:11 - Overnutrition
# * Receiving too many calories each day
# * Unhealthy weight gain leads to cardiovascular disease,
# diabetes, etc.
# * In the United States
# + 1.5 billion adults are overweight
#
# At least 500 million of those are obese
#
# » Malnutrition
# * Ashortage of nutrients the body needs
#
# * Diet lacks adequate proteins, essential lipids, vitamins,
# and minerals
#
#
# 2024-07-13 13:11:23.973 | INFO     | __main__:<module>:11 - The Science Behind the Story (cont’d)
#
# » How Productive Is Organic Farming?
# + Mader’s team found that soil in organic plots had
#
# + Better structure
#
# + Better supply of some nutrients
#
# ss
#
# * Much more microbial activity
# + Much more invertebrate biodiversity
#
# a8
#
#
# 2024-07-13 13:11:23.974 | INFO     | __main__:<module>:11 - » Suitable farmland is disappearing
# + We must improve the efficiency of production
# * We need to raise animals and crops that pollute
# less, require less fuels, and have less impact on
# natural systems
# Sustainable agriculture
# * Maintains healthy soil, clean water, and genetic diversity
# + Treats agricultural systems as ecosystems
# » Low-input agriculture
#
# + Uses smaller amounts of pesticides, fertilizers, growth
# hormones, antibiotics, water, and fossil fuels than
# industrial agriculture
#
#
# 2024-07-13 13:11:23.977 | INFO     | __main__:<module>:11 - * Match crops and climate
#
# * Don't plant crops that require large amounts of water in
# arid climates
#
# * Plant beans or wheat, not rice and cotton
# New technologies improve water use efficiency
#
# + Instead of flood-and-furrow irrigation, drip irrigation can
# increase efficiencies to over 90%
#
#
# 2024-07-13 13:11:23.978 | INFO     | __main__:<module>:11 - * Benefits
# * Reduces pressure on overharvested wild fish
#
# * Uses fewer fossil fuels, is safer, and produces more fish
# than commercial fishing
#
# » Drawbacks
# + Lots of waste produced
# + Uses grain, which affects food supplies for people
# + Fish meal is made from wild ocean fish
# + Escaped fish introduce disease or outcompete wild fish
#
#
# 2024-07-13 13:11:23.978 | INFO     | __main__:<module>:11 - * People make land more vulnerable to erosion by
# * Overcultivating fields: poor planning, excessive tilling
# * Overgrazing rangeland with too many animals
# * Clearing forests on steep slopes or with large clear-cuts
#
#
# 2024-07-13 13:11:23.978 | INFO     | __main__:<module>:11 - Not all insects are pests; some are absolutely vital
# * Over 800 cultivated plants rely on pollinators
# Pollination
# * Male plant sex cells fertilize female sex cells,
# + Flowers are evolutionary adaptations to attract
# pollinators
# * Nectar, pollen, sweet smells, bright colors
#
#
# 2024-07-13 13:11:23.982 | INFO     | __main__:<module>:11 - » Parent material
# + The base geologic material of soil
# Lava, voleanic ash, rock, dunes
# Bedrock: solid rock comprising Earth's crust
# Weathering
# * Physical, chemical, and biological processes that convert
# rocks into soil
# + Biological deposition, decomposition, and
# accumulation provide organic matter and nutrients
# + Humus
#
# + Spongy, fertile material formed by partial decomposition of
# organic matter
#
# Holds moisture and is productive for plants
#
#
# 2024-07-13 13:11:23.983 | INFO     | __main__:<module>:11 - » Agriculture
#
# + Practice of raising crops and livestock for human use and
# consumption
#
# * Cropland
#
# * Land used to raise plants for human use
# » Rangeland
#
# + Land used for grazing livestock
#
# » Land devoted to agriculture now covers 38% of
# Earth's land
#
#
# 2024-07-13 13:11:23.984 | INFO     | __main__:<module>:11 - * Food security
# * Guarantee of an adequate, safe, nutritious, and reliable
# food supply
# * Providing food security to everyone will be one of our
# greatest challenges
# + Undernutrition
# * Receiving fewer calories than one’s minimum dietary
# energy requirements
# * 870 million people suffer from undernutrition
# * Every 5 seconds a child starves to death
# + Poverty, politics, conflict, and inefficiencies in distribution
# contribute to hunger
#
#
# 2024-07-13 13:11:23.984 | INFO     | __main__:<module>:11 - * The U.S. 2014 Farm Bill has provisions to directly
# aid organic agriculture
# + It helps defray certification costs
# The European Union supports farmers financially
# during conversion to organic farming
#
# * Reduced inputs and higher market prices can make it as
# profitable as conventional methods

# %%
# get ocr_lava 
lava_only = df_data_extensive.iloc[4].to_dict().values()

lava_only = list(lava_only)

lava_only = lava_only[1:]

concat_result_ocr_lava = []

# list to a list of strings
ocr_only = [str(i) for i in ocr_only]

lava_only = [str(i) for i in lava_only]

for i in range(len(ocr_only)):
    concat_result_ocr_lava.append(ocr_only[i] + lava_only[i])

# %%
# get ocr_transcriptions
transcriptions = df_data_extensive.iloc[2].to_dict().values()

transcriptions = list(transcriptions)
transcriptions = transcriptions[1:]

concat_result_ocr_transcriptions = []

# concatenate the result 
ocr = ocr_only

transcriptions = [str(i) for i in transcriptions]
ocr_only = [str(i) for i in ocr_only]

# for i in transcriptions:
#     if transcriptions[i] == 'nan' or transcriptions[i] == None:
#         transcriptions[i] = ''

for i in range(len(ocr_only)):
    concat_result_ocr_transcriptions.append(ocr_only[i] + transcriptions[i])

logger.info(concat_result_ocr_transcriptions)
# Out:
# 2024-07-13 13:11:24.540 | INFO     | __main__:<module>:22 - ["+ Feedlots (factory farms)\r\n* Also called concentrated animal feeding operations\r\n(CAFOs)\r\n+ Huge warehouses or pens deliver food to animals living\r\nat extremely high densities\r\n* Produce over half of the world’s pork and most of its\r\npoultry\r\n* Benefits\r\n* Allow greater production of affordable meat\r\n* Reduce grazing impacts on the land\r\n\r\n Feed lots are factory farms are also called concentrated animal feeding operations or CAFOs.  Huge warehouses are penned to liver food to animals living at extremely high densities.  They produce over half of the world's pork and most of its poultry.  The benefits are that it allows a greater production of affordable meat and reduces grazing  impacts on land.  The most expensive meat is the meat that is used for the meat.  The meat is used for the meat.  The meat is used for the meat.  The meat is used for the meat.  The meat is used for the meat.  The meat is used for the meat.  The meat is used for the meat.", 'Resistance to the weed-\r\n\r\nkiller glyphosate is being\r\ndocumented more widely\r\nthan in the past\r\n\r\nClyphosateesistant species\r\n\r\n Resistance to the weed killer glyphosate is being documented more widely than in the past.', "* Soil Conservation Service (SCS)\r\n* Started in 1935 by Congress\r\n* Works with farmers to develop conservation plans for\r\nfarms\r\n+ Now named the Natural Resources Conservation\r\nService\r\nOther countries started their own conservation\r\nagencies\r\n\r\n The Dust Bowl prompted the U.S. to fight erosion and soil conservation services or the  S.C.S. was started in 1935 by Congress. It works with farmers to develop conservation  plans for farms. It's now named the Natural Resources Conservation Service. Other countries  started their own conservation agencies.", 'Biotec’\r\n\r\naround\r\n\r\nnology is transform\r\n\r\nthe produ\r\n\r\n* GM foods have gone from science fiction to\r\nmainstream agriculture in the last 3 decades\r\n\r\n180 5\r\n\r\n460 | — World total ;\r\n440 | — Industrialized nations\r\n420 | — Developing nations\r\n\r\n100\r\n80 4\r\n60\r\n40\r\n20\r\n\r\nns of hectares planted\r\nin GM crops\r\n\r\n Biotechnology is transforming the products around us.  GM foods have gone from science fiction to mainstream agriculture in the last three decades.', "Sustainable agriculture begins with soil\r\nmanagement (cont'd)\r\n* No-till drill\r\n\r\n* Cuts furrow\r\n\r\n* Drops in a seed\r\n\r\n* Closes furrow over seed\r\n* Critics of no-till farming\r\n\r\nin U.S.\r\n\r\n+ Argue that it requires\r\nmore use of chemical herbicides\r\n\r\n+» Proponents\r\n\r\n+ Point out that many farmers rely more heavily on green\r\nmanures by rotating cover crops\r\n\r\n By increasing organic matter and soil biodiversity, while reducing erosion, no-till farming  and conservation tillage can improve soil quality and combat global climate change by storing  carbon and soils.  In the United States today, nearly 1-quarter of farmland is under no-till cultivation and  over 40% under conservation tillage.  This practice no-till farming with a no-till drill.  First, the drill cuts a furrow through the soil surface.  Number 2, it drops in a seed and 3 it closes the furrow over the seed.  This disturbs far less soil than does conventional tilling and reduces erosion rates on  farm fields.  Critics of no-till farming in the U.S. have noted that this approach often requires substantial  use of chemical herbicides because weeds are not physically removed from the fields and  it also requires synthetic fertilizers because non-crop plants take up some of the soil's  nutrients.  And in many industrialized countries, this is indeed been the case.  Proponents of no-till farming, however, point out that in developing countries like South  America, farmers have departed from the industrialized model by relying more heavily on green  menores, which is the dead plants as fertilizers an ...

# %%
# get img_path
img_path = df_data_extensive.iloc[0].to_dict().values()

# convert to list
img_path = list(img_path)
img_path = img_path[1:]

# %%
# Embedd with LLM long summary
logger.info(f"Embedd with LLM long summary")

result = []

embedding_model = EmbeddingsModel()

embedding_model.text_embeddings = None

embedding_model.img_paths = None

embedding_model.img_paths = img_path

embeddings = embedding_model.generate_dataset_embeddings_standard_tokenizer(llm_long_summary)

embedding_model.text_embeddings = embeddings

logger.info(f"Embedding Model.text_embeddings: {embedding_model.text_embeddings}")

rows = []

rows = get_results(df)

df_extensive_summary = pd.DataFrame(rows, columns=['Prompt', 'GT_Keyframe', 'Top_1', 'Top_2', 'Top_3'])

# Save dataframe to CSV
df_extensive_summary.to_csv('df_standard_llm_long_summary_ch7.csv', index=False)
# Out:
# 2024-07-13 13:11:25.108 | INFO     | __main__:<module>:2 - Embedd with LLM long summary
# 2024-07-13 13:11:31.704 | INFO     | __main__:<module>:18 - Embedding Model.text_embeddings: tensor([[-0.3105, -0.2126, -0.0940,  ...,  0.2942,  0.2064, -0.2412],
#         [-0.2912,  0.0772, -0.0872,  ..., -0.1356,  0.1837,  0.0590],
#         [-0.4012, -0.1009, -0.4453,  ...,  0.1038,  0.0645,  0.0591],
#         ...,
#         [ 0.2111,  0.2091,  0.0063,  ..., -0.0335, -0.0541,  0.1448],
#         [ 0.0241,  0.1050, -0.2728,  ..., -0.1618, -0.1975, -0.0643],
#         [ 0.1189,  0.1825, -0.1903,  ..., -0.1839,  0.3104, -0.0752]])
# 2024-07-13 13:11:31.704 | INFO     | __main__:get_results:15 - What are feedlots?
# 2024-07-13 13:11:31.751 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:157 - Top 3 Similarity scores: torch.return_types.topk(
# values=tensor([0.6497, 0.4601, 0.2465]),
# indices=tensor([ 0, 52, 45])) - GT is keyframe number 47
# 2024-07-13 13:11:31.751 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:159 - Length of img paths: 73
# 2024-07-13 13:11:31.751 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 47#####
# 2024-07-13 13:11:31.751 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 0 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-047-01.jpg
# 2024-07-13 13:11:31.751 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 47#####
# 2024-07-13 13:11:31.766 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 52 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-048-01.jpg
# 2024-07-13 13:11:31.766 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 47#####
# 2024-07-13 13:11:31.766 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 45 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-054-01.jpg
# 2024-07-13 13:11:31.766 | INFO     | __main__:get_results:15 - What is weathering?
# 2024-07-13 13:11:31.798 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:157 - Top 3 Similarity scores: torch.return_types.topk(
# values=tensor([0.3249, 0.3045, 0.2916]),
# indices=tensor([55, 12, 57])) - GT is keyframe number 17
# 2024-07-13 13:11:31.798 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:159 - Length of img paths: 73
# 2024-07-13 13:11:31.813 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 17#####
# 2024-07-13 13:11:31.813 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 55 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-027-01.jpg
# 2024-07-13 13:11:31.813 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 17#####
# 2024-07-13 13:11:31.813 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 12 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-026-01.jpg
# 2024-07-13 13:11:31.813 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 17#####
# 2024-07-13 13:11:31.813 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 57 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-023-01.jpg
# 2024-07-13 13:11:31.813 | INFO     | __main__:get_results:15 - What is desertification and how much productivity loss does it cause to arid lands?
# 2024-07-13 13:11:31.876 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:157 - Top 3 Similarity scores: torch.return_types.topk(
# values=tensor([0
| INFO     | src.text_embedder.embedder:search_similar_images_top_k:157 - Top 3 Similarity scores: torch.return_types.topk(
# values=tensor([0.3821, 0.3434, 0.3377]),
# indices=tensor([ 1, 48, 53])) - GT is keyframe number 59
# 2024-07-13 13:11:32.744 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:159 - Length of img paths: 73
# 2024-07-13 13:11:32.744 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 59#####
# 2024-07-13 13:11:32.744 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 1 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-059-01.jpg
# 2024-07-13 13:11:32.744 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 59#####
# 2024-07-13 13:11:32.744 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 48 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-060-01.jpg
# 2024-07-13 13:11:32.744 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 59#####
# 2024-07-13 13:11:32.744 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 53 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-039-01.jpg
# 2024-07-13 13:11:32.759 | INFO     | __main__:get_results:15 - When dod the dust bowl took place?
# 2024-07-13 13:11:32.791 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:157 - Top 3 Similarity scores: torch.return_types.topk(
# values=tensor([0.6278, 0.3002, 0.2414]),
# indices=tensor([57, 51,  2])) - GT is keyframe number 23
# 2024-07-13 13:11:32.791 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:159 - Length of img paths: 73
# 2024-07-13 13:11:32.791 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 23#####
# 2024-07-13 13:11:32.806 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 57 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-023-01.jpg
# 2024-07-13 13:11:32.806 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 23#####
# 2024-07-13 13:11:32.806 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 51 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-035-01.jpg
# 2024-07-13 13:11:32.806 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 23#####
# 2024-07-13 13:11:32.806 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 2 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-024-01.jpg

# %%
# Embedd with OCR ONLY 
logger.info(f"Embedd with OCR ONLY ")

result = []

embedding_model = EmbeddingsModel()

embedding_model.text_embeddings = None

embedding_model.img_paths = None

embedding_model.img_paths = img_path

# need to be embedded

embeddings = embedding_model.generate_dataset_embeddings_standard_tokenizer(ocr_only)

embedding_model.text_embeddings = embeddings

# already embedded 
#
# if isinstance(embedding_model.text_embeddings, list):
#     for i, text_embedding in enumerate(embedding_model.text_embeddings):
#         logger.info(text_embedding)
#         # Regular expression pattern to find numeric values
#         numeric_pattern = r"[-+]?\d*\.\d+(?:[eE][-+]?\d+)?"
#         
#         # Extract numeric values from the tensor string
#         tensor_values_str = re.findall(numeric_pattern, text_embedding)
#         
#         # Convert the extracted string values to float
#         tensor_values = [float(value) for value in tensor_values_str]
#         
#         # Create a PyTorch tensor from the list of floats
#         embedding_model.text_embeddings[i] = torch.tensor(tensor_values)
#         
# 
# # create one single torch for sim search 
# embedding_model.text_embeddings = torch.stack(embedding_model.text_embeddings, dim=0)
# 
# logger.info(f"Embedding Model.text_embeddings: {embedding_model.text_embeddings}")

rows = []

rows = get_results(df)

df_ocr_only = pd.DataFrame(rows, columns=['Prompt', 'GT_Keyframe', 'Top_1', 'Top_2', 'Top_3'])

# Save dataframe to CSV
df_ocr_only.to_csv('df_standard_ocr_only_ch7.csv', index=False)
logger.info('Saved old_df_standard_ocr_only_ch7.csv')
# Out:
# 2024-07-13 13:11:33.106 | INFO     | __main__:<module>:2 - Embedd with OCR ONLY
# 2024-07-13 13:11:38.701 | INFO     | __main__:get_results:15 - What are feedlots?
# 2024-07-13 13:11:38.748 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:157 - Top 3 Similarity scores: torch.return_types.topk(
# values=tensor([0.4588, 0.3192, 0.2023]),
# indices=tensor([ 0, 52, 20])) - GT is keyframe number 47
# 2024-07-13 13:11:38.748 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:159 - Length of img paths: 73
# 2024-07-13 13:11:38.748 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 47#####
# 2024-07-13 13:11:38.748 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 0 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-047-01.jpg
# 2024-07-13 13:11:38.748 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 47#####
# 2024-07-13 13:11:38.748 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 52 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-048-01.jpg
# 2024-07-13 13:11:38.748 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 47#####
# 2024-07-13 13:11:38.748 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 20 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-018-01.jpg
# 2024-07-13 13:11:38.748 | INFO     | __main__:get_results:15 - What is weathering?
# 2024-07-13 13:11:38.801 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:157 - Top 3 Similarity scores: torch.return_types.topk(
# values=tensor([0.2868, 0.2666, 0.2659]),
# indices=tensor([61, 36, 57])) - GT is keyframe number 17
# 2024-07-13 13:11:38.801 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:159 - Length of img paths: 73
# 2024-07-13 13:11:38.801 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 17#####
# 2024-07-13 13:11:38.801 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 61 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-019-01.jpg
# 2024-07-13 13:11:38.801 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 17#####
# 2024-07-13 13:11:38.801 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 36 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-001-01.jpg
# 2024-07-13 13:11:38.801 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 17#####
# 2024-07-13 13:11:38.801 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 57 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-023-01.jpg
# 2024-07-13 13:11:38.801 | INFO     | __main__:get_results:15 - What is desertification and how much productivity loss does it cause to arid lands?
# 2024-07-13 13:11:38.847 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:157 - Top 3 Similarity scores: torch.return_types.topk(
# values=tensor([0.8525, 0.5295, 0.5240]),
# indices=tensor([24, 57, 35])) - GT is keyframe number 22
# 2024-07-13 13:11:38.847 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:159 - Length of img paths: 73
# 2024-07-13 13:11:38.863 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 22#####
# 2024-07-13 13:11:38.863 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 24 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-022-01.jpg
# 2024-07-13 13:11:38.863 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 22#####
# 2024-07-13 13:11:38.863 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 57 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-023-01.jpg
# 2024-07-13 13:11:38.863 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 22#####
# 2024-07-13 13:11:38.863 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 35 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-020-01.jpg
# 2024-07-13 13:11:38.863 | INFO     | __main__:get_results:15 - What is the conservation reserve programm of 1985?
# 2024-07-13 13:11:38.910 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:157 - Top 3 Similarity scores: torch.return_types.topk(
# values=tensor([0.5874, 0.5652, 0.4387]),
# indices=tensor([59,  2, 55])) - GT is keyframe number 29
# 2024-07-13 13:11:38.910 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:159 - Length of img paths: 73
# 2024-07-13 13:11:38.910 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 29#####
# 2024-07-13 13:11:38.910 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 59 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-031-01.jpg
# 2024-07-13 13:11:38.910 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 29#####
# 2024-07-13 13:11:38.910 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 2 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-024-01.jpg
# 2024-07-13 13:11:38.910 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 29#####
# 2024-07-13 13:11:38.910 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 55 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-027-01.jpg
# 2024-07-13 13:11:38.910 | INFO     | __main__:get_results:15 - GM crops today are engineered to resist:
# 2024-07-13 13:11:38.957 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:157 - Top 3 Similarity scores: torch.return_types.topk(
# values=tensor([0.8076, 0.6664, 0.6227]),
# indices=tensor([50, 47, 48])) - GT is keyframe number 56
# 2024-07-13 13:11:38.957 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:159 - Length of img paths: 73
# 2024-07-13 13:11:38.957 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 56#####
# 2024-07-13 13:11:38.957 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 50 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-056-01.jpg
# 2024-07-13 13:11:38.973 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 56#####
# 2024-07-13 13:11:38.973 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 47 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-011-01.jpg
# 2024-07-13 13:11:38.973 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 56#####
# 2024-07-13 13:11:38.973 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 48 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-060-01.jpg
# 2024-07-13 13:11:38.973 | INFO     | __main__:get_results:15 - 90% of energy is lost from one trophic level to the next
# 2024-07-13 13:11:39.004 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:157 - Top 3 Similarity scores: torch.return_types.topk(
# values=tensor([0.5210, 0.3957, 0.3877]),
# indices=tensor([13, 19, 49])) - GT is keyframe number 45
# 2024-07-13 13:11:39.004 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:159 - Length of img paths: 73
# 2024-07-13 13:11:39.004 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 45#####
# 2024-07-13 13:11:39.020 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 13 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-045-01.jpg
# 2024-07-13 13:11:39.020 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 45#####
# 2024-07-13 13:11:39.020 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 19 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-006-01.jpg
# 2024-07-13 13:11:39.020 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 45#####
# 2024-07-13 13:11:39.020 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 49 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-003-01.jpg
# 2024-07-13 13:11:39.020 | INFO     | __main__:get_results:15 - Risks of biocontrol?
# 2024-07-13 13:11:39.067 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:157 - Top 3 Similarity scores: torch.return_types.topk(
# values=tensor([0.5871, 0.4483, 0.3526]),
# indices=tensor([56, 37,  1])) - GT is keyframe number 40
# 2024-07-13 13:11:39.067 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:159 - Length of img paths: 73
# 2024-07-13 13:11
is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-018-01.jpg
# 2024-07-13 13:11:39.681 | INFO     | __main__:get_results:15 - people think that "tinkering" with food but other fear that food supply is dominated by large corporations
# 2024-07-13 13:11:39.728 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:157 - Top 3 Similarity scores: torch.return_types.topk(
# values=tensor([0.6823, 0.5376, 0.5229]),
# indices=tensor([18, 22, 31])) - GT is keyframe number 61
# 2024-07-13 13:11:39.728 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:159 - Length of img paths: 73
# 2024-07-13 13:11:39.728 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 61#####
# 2024-07-13 13:11:39.728 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 18 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-061-01.jpg
# 2024-07-13 13:11:39.728 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 61#####
# 2024-07-13 13:11:39.744 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 22 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-014-01.jpg
# 2024-07-13 13:11:39.744 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 61#####
# 2024-07-13 13:11:39.744 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 31 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-004-01.jpg
# 2024-07-13 13:11:39.744 | INFO     | __main__:get_results:15 - gm foos resistance to the week killer is being documented
# 2024-07-13 13:11:39.791 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:157 - Top 3 Similarity scores: torch.return_types.topk(
# values=tensor([0.4710, 0.3504, 0.3220]),
# indices=tensor([ 1, 48, 50])) - GT is keyframe number 59
# 2024-07-13 13:11:39.791 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:159 - Length of img paths: 73
# 2024-07-13 13:11:39.791 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 59#####
# 2024-07-13 13:11:39.791 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 1 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-059-01.jpg
# 2024-07-13 13:11:39.791 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 59#####
# 2024-07-13 13:11:39.791 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 48 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-060-01.jpg
# 2024-07-13 13:11:39.791 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 59#####
# 2024-07-13 13:11:39.791 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 50 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-056-01.jpg
# 2024-07-13 13:11:39.803 | INFO     | __main__:get_results:15 - When dod the dust bowl took place?
# 2024-07-13 13:11:39.838 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:157 - Top 3 Similarity scores: torch.return_types.topk(
# values=tensor([0.6471, 0.3408, 0.2585]),
# indices=tensor([57,  8, 36])) - GT is keyframe number 23
# 2024-07-13 13:11:39.838 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:159 - Length of img paths: 73
# 2024-07-13 13:11:39.838 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 23#####
# 2024-07-13 13:11:39.838 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 57 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-023-01.jpg
# 2024-07-13 13:11:39.838 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 23#####
# 2024-07-13 13:11:39.838 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 8 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-012-01.jpg
# 2024-07-13 13:11:39.838 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 23#####
# 2024-07-13 13:11:39.852 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 36 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-001-01.jpg
# 2024-07-13 13:11:39.864 | INFO     | __main__:<module>:51 - Saved old_df_standard_ocr_only_ch7.csv

# %%
# Embedd with OCR TRANSCRIPTIONS
# TODO: Doesn't work since transcriptions are nans
logger.info(f"Embedd with TRANSCRIPTIONS")

result = []

embedding_model = EmbeddingsModel()

embedding_model.text_embeddings = None

embedding_model.img_paths = None

embedding_model.img_paths = img_path

embeddings = embedding_model.generate_dataset_embeddings_standard_tokenizer(concat_result_ocr_transcriptions)

embedding_model.text_embeddings = embeddings

logger.info(f"Embedding Model.text_embeddings: {embedding_model.text_embeddings}")

rows = []

rows = get_results(df)

df_ocr_transcriptions = pd.DataFrame(rows, columns=['Prompt', 'GT_Keyframe', 'Top_1', 'Top_2', 'Top_3'])

# Save dataframe to CSV
df_ocr_transcriptions.to_csv('df_standard_df_ocr_transcriptions_ch7.csv', index=False)
# Out:
# 2024-07-13 13:11:40.135 | INFO     | __main__:<module>:3 - Embedd with TRANSCRIPTIONS
# 2024-07-13 13:11:47.819 | INFO     | __main__:<module>:19 - Embedding Model.text_embeddings: tensor([[-4.0239e-02, -9.7657e-02,  7.2754e-02,  ...,  8.3158e-02,
#           4.2901e-01, -1.0000e-01],
#         [-1.7349e-01,  1.1662e-01, -1.8165e-01,  ..., -3.0387e-02,
#           2.6441e-01,  2.4149e-01],
#         [-2.7467e-01, -1.0692e-01, -2.1019e-01,  ...,  1.3203e-01,
#           1.1352e-01,  4.4427e-02],
#         ...,
#         [ 1.3807e-01,  1.0964e-01,  1.3175e-02,  ..., -7.8767e-02,
#           7.5188e-02,  7.9969e-02],
#         [ 3.0522e-02,  1.4148e-01, -6.2367e-02,  ..., -2.1110e-01,
#          -8.1740e-02,  1.0928e-04],
#         [ 1.0573e-01,  1.7724e-01, -1.2145e-01,  ..., -1.9275e-01,
#           3.3453e-01, -6.5827e-02]])
# 2024-07-13 13:11:47.819 | INFO     | __main__:get_results:15 - What are feedlots?
# 2024-07-13 13:11:47.853 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:157 - Top 3 Similarity scores: torch.return_types.topk(
# values=tensor([0.4547, 0.2793, 0.2171]),
# indices=tensor([ 0, 52, 69])) - GT is keyframe number 47
# 2024-07-13 13:11:47.853 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:159 - Length of img paths: 73
# 2024-07-13 13:11:47.853 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 47#####
# 2024-07-13 13:11:47.853 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 0 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-047-01.jpg
# 2024-07-13 13:11:47.853 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 47#####
# 2024-07-13 13:11:47.853 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 52 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-048-01.jpg
# 2024-07-13 13:11:47.853 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 47#####
# 2024-07-13 13:11:47.853 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 69 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-017-01.jpg
# 2024-07-13 13:11:47.869 | INFO     | __main__:get_results:15 - What is weathering?
# 2024-07-13 13:11:47.909 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:157 - Top 3 Similarity scores: torch.return_types.topk(
# values=tensor([0.3085, 0.2558, 0.2506]),
# indices=tensor([61, 55, 67])) - GT is keyframe number 17
# 2024-07-13 13:11:47.909 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:159 - Length of img paths: 73
# 2024-07-13 13:11:47.909 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 17#####
# 2024-07-13 13:11:47.909 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 61 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-019-01.jpg
# 2024-07-13 13:11:47.909 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 17#####
# 2024-07-13 13:11:47.909 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 55 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-027-01.jpg
# 2024-07-13 13:11:47.919 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 17#####
# 2024-07-13 13:11:47.919 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 67 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-021-01.jpg
# 2024-07-13 13:11:47.922 | INFO     | __main__:get_results:15 - What is desertification and how much productivity loss does it cause to arid lands?
# 2024-07-13 13:11:47.969 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:157 - Top 3 Similarity scores: torch.return_types.topk(
# values=tensor([0.8549, 0.5956, 0.5163]),
# indices=tensor([24, 67, 35])) - GT is keyframe number 22
# 2024-07-13 13:11:47.969 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:159 - Length of img paths: 73
# 2024-07-13 13:11:47.969 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 22#####
# 2024-07-13 13:11:47.969 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 24 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-022-01.jpg
# 2024-07-13 13:11:47.969 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 22#####
# 2024-07-13 13:11:47.969 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 67 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-021-01.jpg
# 2024-07-13 13:11:47.969 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 22#####
# 2024-07-13 13:11:47.969 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 35 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-020-01.jpg
# 2024-07-13 13:11:47.969 | INFO     | __main__:get_results:15 - What is the conservation reserve programm of 1985?
# 2024-07-13 13:11:48.019 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:157 - Top 3 Similarity scores: torch.return_types.topk(
# values=tensor([0.6262, 0.5219, 0.4557]),
# indices=tensor([59,  2, 12])) - GT is keyframe number 29
# 2024-07-13 13:11:48.019 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:159 - Length of img paths: 73
# 2024-07-13 13:11:48.019 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 29#####
# 2024-07-13 13:11:48.019 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 59 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-031-01.jpg
# 2024-07-13 13:11:48.019 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 29#####
# 2024-07-13 13:11:48.019 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 2 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-024-01.jpg
# 2024-07-13 13:11:48.019 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 29#####
# 2024-07-13 13:11:48.019 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 12 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-026-01.jpg
# 2024-07-13 13:11:48.019 | INFO     | __main__:get_results:15 - GM crops today are engineered to resist:
# 2024-07-13 13:11:48.063 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:157 - Top 3 Similarity scores: torch.return_types.topk(
# values=tensor([0.8202, 0.6882, 0.6009]),
# indices=tensor([50, 47, 48])) - GT is keyframe number 56
# 2024-07-13 13:11:48.063 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:159 - Length of img paths: 73
# 2024-07-13 13:11:48.063 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 56#####
# 2024-07-13 13:11:48.063 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 50 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene
is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-012-01.jpg

# %%
# Embedd with OCR LAVA
logger.info(f"Embedd with OCR LAVA")

result = []

embedding_model = EmbeddingsModel()

embedding_model.text_embeddings = None

embedding_model.img_paths = None

embedding_model.img_paths = img_path

embeddings = embedding_model.generate_dataset_embeddings_standard_tokenizer(concat_result_ocr_lava)

embedding_model.text_embeddings = embeddings

rows = []

rows = get_results(df)

df_ocr_lava = pd.DataFrame(rows, columns=['Prompt', 'GT_Keyframe', 'Top_1', 'Top_2', 'Top_3'])

# Save dataframe to CSV
df_ocr_lava.to_csv('df_standard_ocr_lava_ch7.csv', index=False)
# Out:
# 2024-07-13 13:11:49.284 | INFO     | __main__:<module>:2 - Embedd with OCR LAVA
# 2024-07-13 13:11:56.424 | INFO     | __main__:get_results:15 - What are feedlots?
# 2024-07-13 13:11:56.451 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:157 - Top 3 Similarity scores: torch.return_types.topk(
# values=tensor([0.4421, 0.3625, 0.3608]),
# indices=tensor([ 0, 45, 52])) - GT is keyframe number 47
# 2024-07-13 13:11:56.451 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:159 - Length of img paths: 73
# 2024-07-13 13:11:56.451 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 47#####
# 2024-07-13 13:11:56.451 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 0 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-047-01.jpg
# 2024-07-13 13:11:56.467 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 47#####
# 2024-07-13 13:11:56.467 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 45 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-054-01.jpg
# 2024-07-13 13:11:56.467 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 47#####
# 2024-07-13 13:11:56.467 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 52 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-048-01.jpg
# 2024-07-13 13:11:56.467 | INFO     | __main__:get_results:15 - What is weathering?
# 2024-07-13 13:11:56.498 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:157 - Top 3 Similarity scores: torch.return_types.topk(
# values=tensor([0.2804, 0.2761, 0.2690]),
# indices=tensor([61, 12, 57])) - GT is keyframe number 17
# 2024-07-13 13:11:56.513 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:159 - Length of img paths: 73
# 2024-07-13 13:11:56.515 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 17#####
# 2024-07-13 13:11:56.515 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 61 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-019-01.jpg
# 2024-07-13 13:11:56.515 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 17#####
# 2024-07-13 13:11:56.515 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 12 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-026-01.jpg
# 2024-07-13 13:11:56.522 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 17#####
# 2024-07-13 13:11:56.522 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 57 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-023-01.jpg
# 2024-07-13 13:11:56.522 | INFO     | __main__:get_results:15 - What is desertification and how much productivity loss does it cause to arid lands?
# 2024-07-13 13:11:56.558 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:157 - Top 3 Similarity scores: torch.return_types.topk(
# values=tensor([0.8431, 0.5236, 0.5215]),
# indices=tensor([24, 35, 33])) - GT is keyframe number 22
# 2024-07-13 13:11:56.558 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:159 - Length of img paths: 73
# 2024-07-13 13:11:56.558 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 22#####
# 2024-07-13 13:11:56.558 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 24 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-022-01.jpg
# 2024-07-13 13:11:56.558 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 22#####
# 2024-07-13 13:11:56.574 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 35 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-020-01.jpg
# 2024-07-13 13:11:56.574 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 22#####
# 2024-07-13 13:11:56.574 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 33 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-032-01.jpg
# 2024-07-13 13:11:56.574 | INFO     | __main__:get_results:15 - What is the conservation reserve programm of 1985?
# 2024-07-13 13:11:56.605 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:157 - Top 3 Similarity scores: torch.return_types.topk(
# values=tensor([0.5988, 0.5397, 0.4736]),
# indices=tensor([59,  2, 55])) - GT is keyframe number 29
# 2024-07-13 13:11:56.605 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:159 - Length of img paths: 73
# 2024-07-13 13:11:56.621 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 29#####
# 2024-07-13 13:11:56.621 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 59 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-031-01.jpg
# 2024-07-13 13:11:56.621 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 29#####
# 2024-07-13 13:11:56.621 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 2 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-024-01.jpg
# 2024-07-13 13:11:56.621 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 29#####
# 2024-07-13 13:11:56.621 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 55 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-027-01.jpg
# 2024-07-13 13:11:56.621 | INFO     | __main__:get_results:15 - GM crops today are engineered to resist:
# 2024-07-13 13:11:56.668 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:157 - Top 3 Similarity scores: torch.return_types.topk(
# values=tensor([0.8221, 0.6428, 0.6003]),
# indices=tensor([50, 47, 48])) - GT is keyframe number 56
# 2024-07-13 13:11:56.668 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:159 - Length of img paths: 73
# 2024-07-13 13:11:56.668 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 56#####
# 2024-07-13 13:11:56.668 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 50 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-056-01.jpg
# 2024-07-13 13:11:56.668 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 56#####
# 2024-07-13 13:11:56.668 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 47 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-011-01.jpg
# 2024-07-13 13:11:56.668 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number
| INFO     | src.text_embedder.embedder:search_similar_images_top_k:157 - Top 3 Similarity scores: torch.return_types.topk(
# values=tensor([0.4018, 0.3898, 0.3838]),
# indices=tensor([32, 71, 66])) - GT is keyframe number 64
# 2024-07-13 13:11:57.313 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:159 - Length of img paths: 73
# 2024-07-13 13:11:57.313 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 64#####
# 2024-07-13 13:11:57.313 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 32 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-051-01.jpg
# 2024-07-13 13:11:57.313 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 64#####
# 2024-07-13 13:11:57.313 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 71 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-005-01.jpg
# 2024-07-13 13:11:57.313 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 64#####
# 2024-07-13 13:11:57.313 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 66 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-050-01.jpg
# 2024-07-13 13:11:57.313 | INFO     | __main__:get_results:15 - What is terracing
# 2024-07-13 13:11:57.360 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:157 - Top 3 Similarity scores: torch.return_types.topk(
# values=tensor([0.4283, 0.4091, 0.4080]),
# indices=tensor([67, 24, 20])) - GT is keyframe number 26
# 2024-07-13 13:11:57.360 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:159 - Length of img paths: 73
# 2024-07-13 13:11:57.360 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 26#####
# 2024-07-13 13:11:57.360 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 67 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-021-01.jpg
# 2024-07-13 13:11:57.360 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 26#####
# 2024-07-13 13:11:57.360 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 24 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-022-01.jpg
# 2024-07-13 13:11:57.360 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 26#####
# 2024-07-13 13:11:57.360 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 20 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-018-01.jpg
# 2024-07-13 13:11:57.360 | INFO     | __main__:get_results:15 - people think that "tinkering" with food but other fear that food supply is dominated by large corporations
# 2024-07-13 13:11:57.407 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:157 - Top 3 Similarity scores: torch.return_types.topk(
# values=tensor([0.6712, 0.5390, 0.5270]),
# indices=tensor([18, 22, 32])) - GT is keyframe number 61
# 2024-07-13 13:11:57.407 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:159 - Length of img paths: 73
# 2024-07-13 13:11:57.407 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 61#####
# 2024-07-13 13:11:57.407 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 18 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-061-01.jpg
# 2024-07-13 13:11:57.407 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 61#####
# 2024-07-13 13:11:57.407 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 22 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-014-01.jpg
# 2024-07-13 13:11:57.407 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 61#####
# 2024-07-13 13:11:57.407 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 32 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-051-01.jpg
# 2024-07-13 13:11:57.422 | INFO     | __main__:get_results:15 - gm foos resistance to the week killer is being documented
# 2024-07-13 13:11:57.470 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:157 - Top 3 Similarity scores: torch.return_types.topk(
# values=tensor([0.4513, 0.3555, 0.3384]),
# indices=tensor([ 1, 48, 14])) - GT is keyframe number 59
# 2024-07-13 13:11:57.470 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:159 - Length of img paths: 73
# 2024-07-13 13:11:57.470 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 59#####
# 2024-07-13 13:11:57.470 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 1 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-059-01.jpg
# 2024-07-13 13:11:57.470 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 59#####
# 2024-07-13 13:11:57.470 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 48 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-060-01.jpg
# 2024-07-13 13:11:57.470 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 59#####
# 2024-07-13 13:11:57.470 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 14 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-038-01.jpg
# 2024-07-13 13:11:57.485 | INFO     | __main__:get_results:15 - When dod the dust bowl took place?
# 2024-07-13 13:11:57.516 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:157 - Top 3 Similarity scores: torch.return_types.topk(
# values=tensor([0.6740, 0.4096, 0.3088]),
# indices=tensor([57,  2, 51])) - GT is keyframe number 23
# 2024-07-13 13:11:57.516 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:159 - Length of img paths: 73
# 2024-07-13 13:11:57.516 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 23#####
# 2024-07-13 13:11:57.516 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 57 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-023-01.jpg
# 2024-07-13 13:11:57.532 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 23#####
# 2024-07-13 13:11:57.532 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 2 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-024-01.jpg
# 2024-07-13 13:11:57.532 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:167 - #####GT is keyframe number 23#####
# 2024-07-13 13:11:57.532 | INFO     | src.text_embedder.embedder:search_similar_images_top_k:168 - Max similarity for index 51 is the keyframe /Users/magic-rabbit/Documents/AFM/afm-vlm/data/raw/ch7_soil_agriculture/extracted_keyframes/ch7_soil_agriculture-Scene-035-01.jpg
